# %% [markdown]
# # OddsJam EV Filters – EDA
#
# This notebook explores bet-level performance by filter and builds baseline features for modeling.

# %%
from oddsjam_ev.io.load import load_bet_tracker_csv

df = load_bet_tracker_csv("data/raw/oddsjam_bet_tracker.csv")
df.head()
